# %% [markdown]
# ## OOP

# %%
# Clase -> Class -> Modelo o plantilla
# Objeto -> Object -> La instancia generada

class Pelicula:
    def __init__(self, titulo, director, anio, puntuacion):
        self.titulo = titulo
        self.director = director
        self.anio = anio
        self.puntuacion = puntuacion

    def mostrar_info(self):
        print(f"{self.titulo} se lanzó en {self.anio}, fue dirigida por {self.director}, con un puntuación en crítica de {self.puntuacion}")

    def inflar_puntuacion(self, puntos):
        self.puntuacion += puntos
        print("¡La puntuación ha sido modificada!")

class Pelicula3D(Pelicula):
    def __init__(self, titulo, director, anio, puntuacion):
        super().__init__(titulo, director, anio, puntuacion)

    def avisar_gafas(self):
        print(f"La pelicula {self.titulo} necesita gafas 3D")

# %%
pelicula_origen = Pelicula("Origen", "Christofer Nolan", 2012, 8.5)
pelicula_toy_story = Pelicula("Toy Story", "John Lasseter", 1995, 8.8)
print(pelicula_origen.__dict__)
print(pelicula_origen.director)

pelicula_origen.mostrar_info()
pelicula_toy_story.mostrar_info()

pelicula_toy_story.inflar_puntuacion(0.5)

pelicula_toy_story.mostrar_info()
# Out:
# {'titulo': 'Origen', 'director': 'Christofer Nolan', 'anio': 2012, 'puntuacion': 8.5}
# Christofer Nolan
# Origen se lanzó en 2012, fue dirigida por Christofer Nolan, con un puntuación en crítica de 8.5
# Toy Story se lanzó en 1995, fue dirigida por John Lasseter, con un puntuación en crítica de 8.8
# ¡La puntuación ha sido modificada!
# Toy Story se lanzó en 1995, fue dirigida por John Lasseter, con un puntuación en crítica de 9.3

# %%
pelicula_avatar = Pelicula3D("Avatar", "James Cameron", 2009, 7.8)

pelicula_avatar.mostrar_info()
pelicula_avatar.avisar_gafas()
# Out:
# Avatar se lanzó en 2009, fue dirigida por James Cameron, con un puntuación en crítica de 7.8
# La pelicula Avatar necesita gafas 3D
