# %% [markdown]
# ## Librerías

# %%
from math import sqrt

numero = 22
raiz_numero = sqrt(numero)
print(raiz_numero)
# Out:
# 4.69041575982343

# %%
import datetime

print(datetime.datetime.today())
# Out:
# 2025-11-17 21:09:59.940480

# %%
import os

print(os.listdir("."))
# Out:
# ['01.intro.ipynb', '02.variablesytipos.ipynb', '03.funciones_built-in.ipynb', '04.operadores.ipynb', '05.strings.ipynb', '06.listas.ipynb', '07.tuplas.ipynb', '08.diccionarios.ipynb', '09.sets.ipynb', '10.condicionales.ipynb', '11.bucles.ipynb', '12.funcionesBuildtIn.ipynb', '13.list_comprehension.ipynb', '14.control_flow.ipynb', '15.funciones.ipynb', '16.funciones.2.ipynb', '17.reduce.ipynb', '18.OOP.ipynb', '19.librerias.ipynb']

# %%
from colorama import Fore, Back, Style

print(Fore.GREEN + 'color verde')
print(Back.BLACK + 'fondo negro')
print(Style.BRIGHT + 'y brillante')
# Out:
# color verde
# fondo negro
# y brillante

# %%
import PySimpleGUI as sg

layout = [
    [sg.Text("Dime como te llamas")],
    [sg.Input(key='-NAME')]
    [sg.Button("saludar")]
    [sg.Text("", key="-SALUDO-")]
]

window = sg.Window("Saludador", layout)

while True:
    event, values = window.read()

    if event == sg.WIN_CLOSED:
        break

    if (event == "Saludar"):
        nombre = values("-NAME-")

window.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import PySimpleGUI as sg
#       3 layout = [
#       4     [sg.Text("Dime como te llamas")],
#       5     [sg.Input(key='-NAME')]
#       6     [sg.Button("saludar")]
#       7     [sg.Text("", key="-SALUDO-")]
#       8 ]
#      10 window = sg.Window("Saludador", layout)
#
# ModuleNotFoundError: No module named 'PySimpleGUI'
